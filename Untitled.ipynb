# %%
import pandas as pd

# %%
data = r"E:\automated_busy_downloads\comp0003\stock_journal\comp0003_stock_journal_2025-01-07 to 2025-01-22.xlsx"
df = pd.read_excel(data,skiprows=3)
df
# Out:
#         Date    Vch/Bill No     Material Centre         Item Details  \
# 0 2025-01-07              1                 PGR   Nova Zyme (In Kgs)
# 1 2025-01-07   RM/STJL24/66   Raw Material Dept              2009 PM
# 2        NaT            NaN                 NaN              2009 RM
# 3 2025-01-08   RM/STJL24/67   Raw Material Dept               824 RM
# 4        NaT            NaN                 NaN       824 RM (Fruit)
# 5 2025-01-15              2                 PGR   Nova Zyme (In Kgs)
# 6 2025-01-18  FU3/STJL24/38  Formulation Unit 3  Balanstick (In Kgs)
# 7        NaT            NaN                 NaN                  NaN
# 8        NaT            NaN                 NaN                  NaN
#
#           Batch No  Batch Qty Batch Narration  Qty. Generated Unit Main  \
# 0  KB/A/NZ/0125/01  3,030.950        NZ/01/01         3030.95       Kgs
# 1  KB2009RM0103L24     59.400             NaN           59.40       Kgs
# ...
